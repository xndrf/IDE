# %% [markdown]
# Для решения задач нам понадобится выделить из признака **title** год выпуска фильма. Для этого напишем функцию **get_year_release(arg)**.
#
# ```
# #библиотека для регулярных выражений
# import re
# def get_year_release(arg):
#     #находим все слова по шаблону "(DDDD)"
#     candidates = re.findall(r'\(\d{4}\)', arg)
#     # проверяем число вхождений
#     if len(candidates) > 0:
#         #если число вхождений больше 0,
# 	#очищаем строку от знаков "(" и ")"
#         year = candidates[0].replace('(', '')
#         year = year.replace(')', '')
#         return int(year)
#     else:
#         #если год не указан, возвращаем None
#         return None
# ```
#
# - Модуль **re** предназначен для поиска шаблонов в тексте и встроен в язык, поэтому не нуждается в установке.
#
# ДОПОЛНИТЕЛЬНО
#
# При желании вы можете ознакомиться с регулярными выражениями по [**ссылке**](https://tproger.ru/translations/regular-expression-python/), однако это не является обязательным для выполнения заданий в этом юните.
#
#
# Из модуля **re** нам понадобится только функция [**findall()**](https://docs-python.ru/standart-library/modul-re-python/funktsija-findall-modulja-re/), которая позволяет найти в строке все слова, удовлетворяющие шаблону. Мы находим в строке с названием фильма шаблон "(DDDD)" — четыре цифры, обёрнутых в скобки, что соответствует году выпуска фильма. Если такого шаблона не было найдено (год выпуска не указан), функция возвращает None (в таблице это будет помечено как пропуск).
#
# > Cовет: для выполнения заданий используйте изученные в этом модуле методы.

# %%
import pandas as pd
data = pd.read_csv('D:\\IDE\\data\\ratings_movies.csv', sep=',')
display (data)
# Out:
#         Unnamed: 0  userId  movieId  rating                 date  \
# 0                0       1        1     4.0  2000-07-30 18:45:03
# 1                1       1        3     4.0  2000-07-30 18:20:47
# 2                2       1        6     4.0  2000-07-30 18:37:04
# 3                3       1       47     5.0  2000-07-30 19:03:35
# 4                4       1       50     5.0  2000-07-30 18:48:51
# ...            ...     ...      ...     ...                  ...
# 100831      100831     610   166534     4.0  2017-05-03 21:53:22
# 100832      100832     610   168248     5.0  2017-05-03 22:21:31
# 100833      100833     610   168250     5.0  2017-05-08 19:50:47
# 100834      100834     610   168252     5.0  2017-05-03 21:19:12
# 100835      100835     610   170875     3.0  2017-05-03 21:20:15
#
#                                  title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# 3          Seven (a.k.a. Se7en) (1995)
# 4           Usual Suspects, The (1995)
# ...                                ...
# 100831                    Split (2017)
# 100832   John Wick: Chapter Two (2017)
# 100833                  Get Out (2017)
# 100834                    Logan (2017)
# 100835  The Fate of the Furious (2017)
#
#                                              genres
# 0       Adventure|Animation|Children|Comedy|Fantasy
# 1                                    Comedy|Romance
# 2                             Action|Crime|Thriller
# 3                                  Mystery|Thriller
# 4                            Crime|Mystery|Thriller
# ...                                             ...
# 100831                        Drama|Horror|Thriller
# 100832                        Action|Crime|Thriller
# 100833                                       Horror
# 100834                                Action|Sci-Fi
# 100835                  Action|Crime|Drama|Thriller
#
# [100836 rows x 7 columns]

# %%
#библиотека для регулярных выражений
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	    #очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %% [markdown]
# # Задание 8.1
#
# Создайте в таблице новый признак **year_release**, который соответствует году выпуска фильма.
# У скольких фильмов не указан год их выпуска?

# %%
data['year_release'] = data['title'].apply(get_year_release)
data.info() # Число непустых значений в столбце можно узнать с помощью метода info().
display(data)

# Число равно всего строк 100836 минус строк в year_rease (100818) =  18
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    100836 non-null  int64
#  1   userId        100836 non-null  int64
#  2   movieId       100836 non-null  int64
#  3   rating        100836 non-null  float64
#  4   date          100836 non-null  datetime64[ns]
#  5   title         100836 non-null  object
#  6   genres        100836 non-null  object
#  7   year_rating   100836 non-null  int64
#  8   year_release  100818 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(2)
# memory usage: 6.9+ MB
#         Unnamed: 0  userId  movieId  rating                date  \
# 0                0       1        1     4.0 2000-07-30 18:45:03
# 1                1       1        3     4.0 2000-07-30 18:20:47
# 2                2       1        6     4.0 2000-07-30 18:37:04
# 3                3       1       47     5.0 2000-07-30 19:03:35
# 4                4       1       50     5.0 2000-07-30 18:48:51
# ...            ...     ...      ...     ...                 ...
# 100831      100831     610   166534     4.0 2017-05-03 21:53:22
# 100832      100832     610   168248     5.0 2017-05-03 22:21:31
# 100833      100833     610   168250     5.0 2017-05-08 19:50:47
# 100834      100834     610   168252     5.0 2017-05-03 21:19:12
# 100835      100835     610   170875     3.0 2017-05-03 21:20:15
#
#                                  title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# 3          Seven (a.k.a. Se7en) (1995)
# 4           Usual Suspects, The (1995)
# ...                                ...
# 100831                    Split (2017)
# 100832   John Wick: Chapter Two (2017)
# 100833                  Get Out (2017)
# 100834                    Logan (2017)
# 100835  The Fate of the Furious (2017)
#
#                                              genres  year_rating  year_release
# 0       Adventure|Animation|Children|Comedy|Fantasy         2000        1995.0
# 1                                    Comedy|Romance         2000        1995.0
# 2                             Action|Crime|Thriller         2000        1995.0
# 3                                  Mystery|Thriller         2000        1995.0
# 4                            Crime|Mystery|Thriller         2000        1995.0
# ...                                             ...          ...           ...
# 100831                        Drama|Horror|Thriller         2017        2017.0
# 100832                        Action|Crime|Thriller         2017        2017.0
# 100833                                       Horror         2017        2017.0
# 100834                                Action|Sci-Fi         2017        2017.0
# 100835                  Action|Crime|Drama|Thriller         2017        2017.0
#
# [100836 rows x 9 columns]

# %% [markdown]
# # Задание 8.2
#
# Какой фильм, выпущенный в 1999 году, получил наименьшую среднюю оценку зрителей?
# В качестве ответа запишите название этого фильма без указания года его выпуска.

# %%
mask = data['year_release'] == 1999  # задаём параметр
film = data[mask].groupby('title')['rating'].mean().sort_values() # При условии параметра, выводим фильмы по среднему рейтингу, в режиме сортировки
display(film.head(1)) # Выводим первое значение таблицы
# Out:
# title
# Bloodsport: The Dark Kumite (1999)    0.5
# Name: rating, dtype: float64

# %% [markdown]
# # Задание 8.3
#
# Какое сочетание жанров фильмов (genres), выпущенных в 2010 году, получило наименьшую среднюю оценку (rating)?
# Запишите сочетание так же, как оно указано в таблице (через разделитель |, без пробелов).

# %%
mask = data['year_release'] == 2010  # задаём параметр
data[mask].groupby('genres')['rating'].mean().sort_values()
# Out:
# genres
# Action|Sci-Fi                        1.000000
# Action|Adventure|Horror              1.500000
# Action|Drama|Fantasy                 1.500000
# Crime|Romance                        1.500000
# Adventure|Comedy|Fantasy             1.833333
#                                        ...
# Crime                                4.750000
# Comedy|Musical                       5.000000
# Animation|Drama|Fantasy|Mystery      5.000000
# Adventure|Children|Comedy|Mystery    5.000000
# Animation|Children|Mystery           5.000000
# Name: rating, Length: 119, dtype: float64

# %% [markdown]
# # Задание 8.4
#
# Какой пользователь (userId) посмотрел наибольшее количество различных (уникальных) комбинаций жанров (genres) фильмов? В качестве ответа запишите идентификатор этого пользователя.

# %%
data.groupby('userId')['genres'].nunique().sort_values(ascending=False) # nunique()- число уникальных значений, сортируем в обратном порядке
# Out:
# userId
# 599    524
# 414    482
# 448    403
# 380    399
# 474    395
#       ...
# 578     15
# 12      15
# 85      13
# 214     13
# 245     13
# Name: genres, Length: 610, dtype: int64

# %% [markdown]
# # Задание 8.5
#
# Найдите пользователя, который выставил наименьшее количество оценок, но его средняя оценка фильмам наибольшая.
# В качестве ответа укажите идентификатор этого пользователя.
# Чтобы рассчитать несколько параметров для каждого пользователя (количество оценок и среднюю оценку), можно воспользоваться методом agg() на сгруппированных данных.

# %%
data.groupby('userId')['rating'].agg(   # agg - для нескольких аргументов. Смотрим Номер пользователя, который выставил рейтинг
    ['nunique', 'mean']                 # уникальных значений (сколько раз выставил оценку), среднее значение по оценкам
    ).sort_values(by='nunique', ascending=True)  # сортировка по уникальным значениям, от наименьшего к большему.
# Out:
#         nunique      mean
# userId
# 53            1  5.000000
# 49            2  4.261905
# 609           2  3.270270
# 404           2  3.400000
# 470           3  3.512500
# ...         ...       ...
# 359          10  3.418919
# 365          10  2.750903
# 382          10  3.508591
# 322          10  3.411215
# 610          10  3.688556
#
# [610 rows x 2 columns]

# %% [markdown]
# # Задание 8.6
#
# Найдите сочетание жанров (genres) за 2018 году, которое имеет наибольший средний рейтинг (среднее по столбцу rating), и при этом число выставленных ему оценок (количество значений в столбце rating) больше 10.
# Запишите сочетание так же, как оно указано в таблице (через разделитель |, без пробелов).

# %%
mask_1 = data['year_release'] == 2018 # задаем год интересующий
grouped = data[mask_1].groupby('genres')['rating'].agg(   #группируем по году жанры по рейтингу 
    ['mean', 'count'] # (средний рейтинг, количество выставленных оценок)
)
grouped[grouped['count']>10].sort_values(by='mean', ascending=True) # групируем при количестве больше 10, сортируем по среднему значению, от меньшего к большему
# Out:
#                              mean  count
# genres
# Action|Comedy|Sci-Fi     3.875000     12
# Action|Adventure|Sci-Fi  3.928571     14

# %% [markdown]
# # Задание 8.7
#
# Добавьте в таблицу новый признак year_rating — год выставления оценки. Создайте сводную таблицу, которая иллюстрирует зависимость среднего рейтинга фильма от года выставления оценки и жанра. Выберите верные варианты ответа, исходя из построенной таблицы:
# - A За весь период (с 1996 по 2018 год) сочетание жанров Action|Adventure ни разу не получало среднюю оценку ниже 3.
# - B Наилучшую оценку жанр Action|Adventure|Animation|Children|Comedy|IMAX получил в 2010 году.
# - C Среди сочетаний жанров, получивших наивысшую среднюю оценку в 2018 году, есть сочетание Animation|Children|Mystery.
# - D Для жанра Comedy прослеживается тенденция падения рейтинга с каждым годом (с 1996 по 2018).

# %%
data['date'] = pd.to_datetime(data['date'], dayfirst=True)
data['year_rating'] = data['date'].dt.year
pivot = data.pivot_table(
    values='rating',
    index='year_rating',
    columns='genres',
    aggfunc='mean' # можно не указывать, по стандарту используется mean. Добавил для раскрытия полного
)
display(pivot)
# Out:
# genres       (no genres listed)    Action  Action|Adventure  \
# year_rating
# 1996                        NaN  2.730769          3.454545
# 1997                        NaN  3.538462          4.150000
# 1998                        NaN       NaN          4.200000
# 1999                        NaN       NaN          4.000000
# 2000                        NaN  2.588235          3.738462
# 2001                        NaN  3.000000          3.500000
# 2002                        NaN  2.750000          4.304348
# 2003                        NaN  3.833333          3.277778
# 2004                        NaN  2.700000          4.136364
# 2005                        NaN  3.357143          3.413043
# 2006                        NaN  2.166667          4.090909
# 2007                        NaN  2.583333          3.666667
# 2008                        NaN  3.000000          3.656250
# 2009                        NaN       NaN          3.714286
# 2010                        NaN  3.500000          3.437500
# 2011                        NaN  4.500000          3.888889
# 2012                        NaN  2.625000          3.900000
# 2013                        NaN  2.500000          3.833333
# 2014                        NaN       NaN          3.875000
# 2015                   0.500000  3.100000          3.560976
# 2016                   3.500000  3.545455          3.722222
# 2017                   3.000000  2.637931          3.527778
# 2018                   3.676471  2.588235          3.397436
#
# genres       Action|Adventure|Animation  Action|Adventure|Animation|Children  \
# year_rating
# 1996                                NaN                                  NaN
# 1997                                NaN                                  NaN
# 1998                                NaN                                  NaN
# 1999                                NaN                                  NaN
# 2000                                NaN                                  NaN
# 2001                                NaN                                  NaN
# 2002                                NaN                                  NaN
# 2003                                NaN                                  NaN
# 2004                                NaN                                  NaN
# 2005                                NaN                                  NaN
# 2006                                NaN                                  NaN
# 2007                                NaN                                  NaN
# 2008                                NaN                                  NaN
# 2009                                NaN                                  NaN
# 2010                                NaN                                  NaN
# 2011                                NaN                                  NaN
# 2012                                NaN                             4.000000
# 2013                                NaN                             3.000000
# 2014                              3.000                             3.500000
# 2015                              3.800                             3.666667
# 2016                              3.750                             3.833333
# 2017                              3.375                             3.500000
# 2018                              3.650                             3.166667
#
# genres       Action|Adventure|Animation|Children|Comedy  \
# year_rating
# 1996                                                NaN
# 1997                                                NaN
# 1998                                                NaN
# 1999                                                NaN
# 2000                                                NaN
# 2001                                                NaN
# 2002                                                NaN
# 2003                                                NaN
# 2004                                           4.000000
# 2005                                           4.107143
# 2006                                           3.833333
# 2007                                           3.846154
# 2008                                           4.125000
# 2009                                           3.900000
# 2010                                           4.333333
# 2011                                           3.500000
# 2012                                           3.785714
# 2013                                           4.333333
# 2014                                           3.250000
# 2015                                           3.565217
# 2016                                           3.925000
# 2017                                           3.676471
# 2018                                           3.741935
#
# genres       Action|Adventure|Animation|Children|Comedy|Fantasy  \
# year_rating
# 1996                                                       NaN
# 1997                                                       NaN
# 1998                                                       NaN
# 1999                                                       NaN
# 2000                                                       NaN
# 2001                                                       NaN
# 2002                                                       NaN
# 2003                                                       NaN
# 2004                                                       NaN
# 2005                                                       NaN
# 2006                                                       NaN
# 2007                                                  3.000000
# 2008                                                  4.000000
# 2009                                                       NaN
# 2010                                                       NaN
# 2011                                                       NaN
# 2012                                                       NaN
# 2013                                                       NaN
# 2014                                                  3.833333
# 2015                                                  3.833333
# 2016                                                  3.388889
# 2017                                                  3.700000
# 2018                                                  4.142857
#
# genres       Action|Adventure|Animation|Children|Comedy|IMAX  \
# year_rating
# 1996                                                     NaN
# 1997                                                     NaN
# 1998                                                     NaN
# 1999                                                     NaN
# 2000                                                     NaN
# 2001                                                     NaN
# 2002                                                     NaN
# 2003                                                     NaN
# 2004                                                     NaN
# 2005                                                     NaN
# 2006                                                     NaN
# 2007                                                     NaN
# 2008                                                     NaN
# 2009                                                3.250000
# 2010                                                3.500000
# 2011                                                     NaN
# 2012                                                3.550000
# 2013                                                5.000000
# 2014                                                3.500000
# 2015                                                3.375000
# 2016                                                3.666667
# 2017                                                1.000000
# 2018                                                3.700000
#
# genres       Action|Adventure|Animation|Children|Comedy|Romance  \
# year_rating
# 1996                                                       NaN
# 1997                                                       NaN
# 1998                                                       NaN
# 1999                                                       NaN
# 2000                                                       NaN
# 2001                                                       NaN
# 2002                                                       NaN
# 2003                                                       NaN
# 2004                                                       NaN
# 2005                                                       NaN
# 2006                                                       NaN
# 2007                                                       NaN
# 2008                                                       NaN
# 2009                                                       NaN
# 2010                                                  3.000000
# 2011                                                       NaN
# 2012                                                  4.000000
# 2013                                                       NaN
# 2014                                                  4.000000
# 2015                                                  2.333333
# 2016                                                  1.000000
# 2017                                                  1.000000
# 2018                                                  2.500000
#
# genres       Action|Adventure|Animation|Children|Comedy|Sci-Fi  ...  \
# year_rating                                                     ...
# 1996                                                       NaN  ...
# 1997                                                       NaN  ...
# 1998                                                       NaN  ...
# 1999                                                       NaN  ...
# 2000                                                       NaN  ...
# 2001                                                       NaN  ...
# 2002                                                       NaN  ...
# 2003                                                       NaN  ...
# 2004                                                       NaN  ...
# 2005                                                       NaN  ...
# 2006                                                       3.0  ...
# 2007                                                       2.8  ...
# 2008                                                       3.5  ...
# 2009                                                       2.5  ...
# 2010                                                       NaN  ...
# 2011                                                       4.0  ...
# 2012                                                       NaN  ...
# 2013                                                       NaN  ...
# 2014                                                       NaN  ...
# 2015                                                       2.5  ...
# 2016                                                       4.0  ...
# 2017                                                       2.0  ...
# 2018                                                       4.0  ...
#
# genres       Romance|Thriller  Romance|War  Romance|Western    Sci-Fi  \
# year_rating
# 1996                      NaN          NaN              NaN       NaN
# 1997                      NaN          NaN              NaN       NaN
# 1998                      NaN          NaN              NaN       NaN
# 1999                    2.000          NaN              NaN       NaN
# 2000                    4.000          NaN              3.0  3.416667
# 2001                      NaN          NaN              3.0  2.500000
# 2002                    3.000          NaN              NaN  3.750000
# 2003                    3.375          2.5              NaN  2.333333
# 2004                    3.000          3.0              3.5  2.125000
# 2005                    2.000          NaN              NaN  3.000000
# 2006                      NaN          NaN              NaN  0.500000
# 2007                    1.500          NaN              2.5  3.375000
# 2008                      NaN          NaN              NaN  3.125000
# 2009                      NaN          NaN              NaN  2.000000
# 2010                      NaN          NaN              NaN  4.000000
# 2011                      NaN          NaN              NaN  3.500000
# 2012                    2.500          NaN              NaN  4.166667
# 2013                      NaN          NaN              NaN  1.500000
# 2014                      NaN          NaN              NaN  2.500000
# 2015                      NaN          NaN              NaN  2.900000
# 2016                    2.500          NaN              NaN  3.555556
# 2017                    3.000          NaN              NaN  3.864865
# 2018                      NaN          NaN              NaN  3.128571
#
# genres       Sci-Fi|IMAX  Sci-Fi|Thriller  Sci-Fi|Thriller|IMAX  Thriller  \
# year_rating
# 1996                 NaN         2.666667                   NaN  3.838095
# 1997                 NaN         3.400000                   NaN  3.923077
# 1998                 NaN              NaN                   NaN  3.800000
# 1999                 NaN         4.000000                   NaN  3.700000
# 2000                 NaN         2.142857                   NaN  3.087912
# 2001                 NaN         2.500000                   NaN  3.477273
# 2002                 NaN         3.600000                   NaN  3.583333
# 2003                 NaN         3.142857                   NaN  3.250000
# 2004                 NaN              NaN                   NaN  3.464286
# 2005                 NaN         2.750000                   NaN  3.411765
# 2006                 NaN         4.500000                   NaN  3.735294
# 2007                 NaN         2.833333                   NaN  3.421875
# 2008                 NaN         3.000000                   NaN  3.333333
# 2009                 NaN         4.000000                   NaN  2.964286
# 2010                 NaN         2.500000                   NaN  2.833333
# 2011                 NaN         1.833333              4.000000  3.625000
# 2012                 NaN         3.500000              3.666667  3.083333
# 2013                 NaN         3.833333              4.000000  3.666667
# 2014            5.000000              NaN              4.000000  4.000000
# 2015            4.071429         3.764706              4.000000  2.911765
# 2016            3.807692         3.916667              3.666667  3.432432
# 2017            4.264706         3.750000              2.500000  3.152174
# 2018            3.500000         3.562500                   NaN  3.296296
#
# genres       War   Western
# year_rating
# 1996         NaN  3.117647
# 1997         NaN  3.000000
# 1998         NaN       NaN
# 1999         4.5  4.000000
# 2000         3.0  4.058824
# 2001         3.0  3.111111
# 2002         3.5  3.000000
# 2003         3.0  4.000000
# 2004         3.0  3.800000
# 2005         NaN  4.500000
# 2006         NaN  3.625000
# 2007         NaN  3.000000
# 2008         NaN  4.000000
# 2009         4.0  3.375000
# 2010         NaN  3.666667
# 2011         NaN  4.000000
# 2012         NaN  4.100000
# 2013         NaN  4.000000
# 2014         NaN  4.000000
# 2015         NaN  3.900000
# 2016         NaN  3.958333
# 2017         NaN  2.933333
# 2018         NaN  3.611111
#
# [23 rows x 951 columns]

# %%
pivot['2018'].sort_values()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2018'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 pivot['2018'].sort_values()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: '2018'

# %% [markdown]
# # Задание 8.8 - 8.10
# Дано два файла:
#
# orders.csv, содержащий данные о заказах;
# products.csv, содержащий данные о товарах.
# Скачать файлы можно здесь (оба файла находятся в едином zip-архиве — распакуйте его, прежде чем продолжать работу!)
#
# Прочитайте данные файлы, посмотрите на содержимое таблиц и проанализируйте его.
#
# Подумайте, как связаны данные таблицы (какими ключевыми столбцами).
#
# Объедините заданные таблицы в таблицу orders_products, чтобы в результирующей таблице оказалась информация обо всех заказах, но не оказалось информации о продуктах, на которых заказов ещё не поступало.
#
# Ответьте на несколько вопросов по таблице orders_products ↓

# %%
import pandas as pd
orders = pd.read_csv('D:\\IDE\\data\\orders.csv', sep=';')
products = pd.read_csv('D:\\IDE\\data\\products.csv', sep=';')

display (orders, products)
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
#                              Статус Оплачен Отменен Отгружен  ID товара  \
# 0          Принят, ожидается оплата     Нет     Нет      Нет        103
# 1          Принят, ожидается оплата     Нет     Нет      Нет         86
# 2          Принят, ожидается оплата     Нет     Нет      Нет        104
# 3          Принят, ожидается оплата     Нет     Нет      Нет        104
# 4          Принят, ожидается оплата     Нет     Нет      Нет        104
# 5          Принят, ожидается оплата     Нет     Нет      Нет        103
# 6                           Отменён     Нет      Да      Нет        124
# 7          Принят, ожидается оплата     Нет     Нет       Да         91
# 8   Оплачен, формируется к отправке      Да     Нет      Нет        103
# 9   Оплачен, формируется к отправке      Да     Нет      Нет        104
# 10                         Выполнен      Да     Нет       Да         74
# 11                         Выполнен      Да     Нет       Да         53
# 12                         Выполнен      Да     Нет       Да        137
# 13                         Выполнен      Да     Нет       Да         47
# 14  Оплачен, формируется к отправке      Да     Нет      Нет         71
# 15  Оплачен, формируется к отправке      Да     Нет      Нет         86
# 16  Оплачен, формируется к отправке      Да     Нет      Нет         51
# 17  Оплачен, формируется к отправке      Да     Нет      Нет        666
#
#     Количество
# 0            5
# 1          100
# 2           10
# 3            7
# 4            5
# 5            5
# 6            1
# 7            1
# 8            3
# 9            3
# 10           1
# 11           1
# 12           1
# 13           1
# 14           1
# 15           1
# 16           1
# 17           1
#     Product_ID                                   Name  Price CURRENCY
# 0           47                   Шатны Полосатый рейс   2999      RUR
# 1           51               Платье Аленький цветочек   4999      RUR
# 2           53                 Штаны Цветочная Поляна   4999      RUR
# 3           71                    Платье Ночная Жизнь   7999      RUR
# 4           74               Платье Ночная Жизнь XXXL   8999      RUR
# 5           86                     Носки Простые, муж     45      RUR
# 6           91                     Носки Честные, муж     50      RUR
# 7          103                  Носки Подарочные, муж    199      RUR
# 8          104                  Носки Подарочные, жен    249      RUR
# 9          124                   Носки беговые Camino    999      RUR
# 10         137              Гольфы детские Снегурочка     99      RUR
# 11         138               Гольфы детские Питер Пен     99      RUR
# 12         139                       Сумка для носков    500      RUR
# 13         140  Товар, которому не придумано название      1      RUR

# %%
# Мой вариант создания таблицы

orders_product = products.merge(
    orders,
    left_on = 'Product_ID',
    right_on='ID товара',
    how = 'outer'
)
orders_product = orders_product.drop(['ID товара'], axis = 1) # Удаляем лишнюю строку
display(orders_product)

# Эталонный вариант создания таблицы

orders_product_ET = orders.merge(
    products, 
    left_on='ID товара',
    right_on='Product_ID',
    how='left')
display(orders_product_ET)
# Out:
#     Product_ID                                   Name   Price CURRENCY  \
# 0         47.0                   Шатны Полосатый рейс  2999.0      RUR
# 1         51.0               Платье Аленький цветочек  4999.0      RUR
# 2         53.0                 Штаны Цветочная Поляна  4999.0      RUR
# 3         71.0                    Платье Ночная Жизнь  7999.0      RUR
# 4         74.0               Платье Ночная Жизнь XXXL  8999.0      RUR
# 5         86.0                     Носки Простые, муж    45.0      RUR
# 6         86.0                     Носки Простые, муж    45.0      RUR
# 7         91.0                     Носки Честные, муж    50.0      RUR
# 8        103.0                  Носки Подарочные, муж   199.0      RUR
# 9        103.0                  Носки Подарочные, муж   199.0      RUR
# 10       103.0                  Носки Подарочные, муж   199.0      RUR
# 11       104.0                  Носки Подарочные, жен   249.0      RUR
# 12       104.0                  Носки Подарочные, жен   249.0      RUR
# 13       104.0                  Носки Подарочные, жен   249.0      RUR
# 14       104.0                  Носки Подарочные, жен   249.0      RUR
# 15       124.0                   Носки беговые Camino   999.0      RUR
# 16       137.0              Гольфы детские Снегурочка    99.0      RUR
# 17       138.0               Гольфы детские Питер Пен    99.0      RUR
# 18       139.0                       Сумка для носков   500.0      RUR
# 19       140.0  Товар, которому не придумано название     1.0      RUR
# 20         NaN                                    NaN     NaN      NaN
#
#           Дата создания  Order ID  ID Покупателя  \
# 0   08.11.2019 08:36:21       2.0            7.0
# 1   08.11.2019 08:36:20       1.0            5.0
# 2   08.11.2019 08:36:21       2.0            7.0
# 3   08.11.2019 08:36:20       1.0            5.0
# 4   08.11.2019 08:36:21       2.0            7.0
# 5   09.11.2019 15:05:57       8.0            9.0
# 6   08.11.2019 08:36:20       1.0            5.0
# 7   08.11.2019 08:36:22       4.0            9.0
# 8   09.11.2019 21:55:51       9.0           10.0
# 9   09.11.2019 12:00:00       6.0            1.0
# 10  08.11.2019 08:36:22       3.0            8.0
# 11  09.11.2019 15:05:57       8.0            9.0
# 12  09.11.2019 12:50:07       7.0            8.0
# 13  09.11.2019 12:00:00       6.0            1.0
# 14  08.11.2019 08:36:22       3.0            8.0
# 15  08.11.2019 08:36:22       5.0            5.0
# 16  08.11.2019 08:36:21       2.0            7.0
# 17                  NaN       NaN            NaN
# 18                  NaN       NaN            NaN
# 19                  NaN       NaN            NaN
# 20  01.01.2001 00:00:00       0.0            1.0
#
#                              Статус Оплачен Отменен Отгружен  Количество
# 0                          Выполнен      Да     Нет       Да         1.0
# 1   Оплачен, формируется к отправке      Да     Нет      Нет         1.0
# 2                          Выполнен      Да     Нет       Да         1.0
# 3   Оплачен, формируется к отправке      Да     Нет      Нет         1.0
# 4                          Выполнен      Да     Нет       Да         1.0
# 5          Принят, ожидается оплата     Нет     Нет      Нет       100.0
# 6   Оплачен, формируется к отправке      Да     Нет      Нет         1.0
# 7          Принят, ожидается оплата     Нет     Нет       Да         1.0
# 8          Принят, ожидается оплата     Нет     Нет      Нет         5.0
# 9          Принят, ожидается оплата     Нет     Нет      Нет         5.0
# 10  Оплачен, формируется к отправке      Да     Нет      Нет         3.0
# 11         Принят, ожидается оплата     Нет     Нет      Нет        10.0
# 12         Принят, ожидается оплата     Нет     Нет      Нет         7.0
# 13         Принят, ожидается оплата     Нет     Нет      Нет         5.0
# 14  Оплачен, формируется к отправке      Да     Нет      Нет         3.0
# 15                          Отменён     Нет      Да      Нет         1.0
# 16                         Выполнен      Да     Нет       Да         1.0
# 17                              NaN     NaN     NaN      NaN         NaN
# 18                              NaN     NaN     NaN      NaN         NaN
# 19                              NaN     NaN     NaN      NaN         NaN
# 20  Оплачен, формируется к отправке      Да     Нет      Нет         1.0
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
#                              Статус Оплачен Отменен Отгружен  ID товара  \
# 0          Принят, ожидается оплата     Нет     Нет      Нет        103
# 1          Принят, ожидается оплата     Нет     Нет      Нет         86
# 2          Принят, ожидается оплата     Нет     Нет      Нет        104
# 3          Принят, ожидается оплата     Нет     Нет      Нет        104
# 4          Принят, ожидается оплата     Нет     Нет      Нет        104
# 5          Принят, ожидается оплата     Нет     Нет      Нет        103
# 6                           Отменён     Нет      Да      Нет        124
# 7          Принят, ожидается оплата     Нет     Нет       Да         91
# 8   Оплачен, формируется к отправке      Да     Нет      Нет        103
# 9   Оплачен, формируется к отправке      Да     Нет      Нет        104
# 10                         Выполнен      Да     Нет       Да         74
# 11                         Выполнен      Да     Нет       Да         53
# 12                         Выполнен      Да     Нет       Да        137
# 13                         Выполнен      Да     Нет       Да         47
# 14  Оплачен, формируется к отправке      Да     Нет      Нет         71
# 15  Оплачен, формируется к отправке      Да     Нет      Нет         86
# 16  Оплачен, формируется к отправке      Да     Нет      Нет         51
# 17  Оплачен, формируется к отправке      Да     Нет      Нет        666
#
#     Количество  Product_ID                       Name   Price CURRENCY
# 0            5       103.0      Носки Подарочные, муж   199.0      RUR
# 1          100        86.0         Носки Простые, муж    45.0      RUR
# 2           10       104.0      Носки Подарочные, жен   249.0      RUR
# 3            7       104.0      Носки Подарочные, жен   249.0      RUR
# 4            5       104.0      Носки Подарочные, жен   249.0      RUR
# 5            5       103.0      Носки Подарочные, муж   199.0      RUR
# 6            1       124.0       Носки беговые Camino   999.0      RUR
# 7            1        91.0         Носки Честные, муж    50.0      RUR
# 8            3       103.0      Носки Подарочные, муж   199.0      RUR
# 9            3       104.0      Носки Подарочные, жен   249.0      RUR
# 10           1        74.0   Платье Ночная Жизнь XXXL  8999.0      RUR
# 11           1        53.0     Штаны Цветочная Поляна  4999.0      RUR
# 12           1       137.0  Гольфы детские Снегурочка    99.0      RUR
# 13           1        47.0       Шатны Полосатый рейс  2999.0      RUR
# 14           1        71.0        Платье Ночная Жизнь  7999.0      RUR
# 15           1        86.0         Носки Простые, муж    45.0      RUR
# 16           1        51.0   Платье Аленький цветочек  4999.0      RUR
# 17           1         NaN                        NaN     NaN      NaN

# %% [markdown]
# # Задание 8.8
#
# Какой идентификатор (Order ID) имеет заказ, для которого не оказалось информации о товаре?

# %% [markdown]
# #### Вариант 1

# %%
orders_product = orders_product.fillna(0) # Замена значения Nan на ноль во всех столбцах
mask_3 = orders_product['Name'] == 0 # Создаем маску для поиска нулевых значений
orders_product[mask_3].sort_values(by='Name')
# Out:
#     Product_ID Name  Price CURRENCY        Дата создания  Order ID  \
# 20         0.0    0    0.0        0  01.01.2001 00:00:00       0.0
#
#     ID Покупателя                           Статус Оплачен Отменен Отгружен  \
# 20            1.0  Оплачен, формируется к отправке      Да     Нет      Нет
#
#     Количество
# 20         1.0

# %% [markdown]
# #### Вариант 2

# %%
orders_product_ET[orders_product_ET['Name'].isna()] # там где Nan
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 17  01.01.2001 00:00:00         0              1
#
#                              Статус Оплачен Отменен Отгружен  ID товара  \
# 17  Оплачен, формируется к отправке      Да     Нет      Нет        666
#
#     Количество  Product_ID Name  Price CURRENCY
# 17           1         NaN  NaN    NaN      NaN

# %% [markdown]
# # Задание 8.9
#
# На какой товар была произведена отмена?
# В качестве ответа запишите название этого товара (Name).

# %% [markdown]
# #### Вариант решения мой

# %%
mask = orders_product['Отменен'] == 'Да'
orders_product[mask].sort_values(by='Отменен')
# Out:
#     Product_ID                  Name  Price CURRENCY        Дата создания  \
# 15       124.0  Носки беговые Camino  999.0      RUR  08.11.2019 08:36:22
#
#     Order ID  ID Покупателя   Статус Оплачен Отменен Отгружен  Количество
# 15       5.0            5.0  Отменён     Нет      Да      Нет         1.0

# %% [markdown]
# #### Эталонное решение

# %%
orders_product_ET[orders_product_ET['Отменен'] == 'Да']['Name']
# Out:
# 6    Носки беговые Camino
# Name: Name, dtype: object

# %% [markdown]
# # Задание 8.10
#
# Какой покупатель принёс наибольшую суммарную прибыль интернет-магазину за указанный период?
# В ответ запишите идентификатор этого покупателя (ID Покупателя).
#
# Прибыль состоит только из оплаченных заказов и рассчитывается как количество купленного товара, умноженное на его цену.

# %% [markdown]
# #### Мой вариант решения

# %%
prav = orders_product['Оплачен'] == 'Да' # Создали маску, где оплачены продукты
orders_product_2 = orders_product[prav] # Создали новую таблицу, согласно новому условию
orders_product_2['Sum'] = orders_product_2['Количество'] * orders_product_2['Price'] # Создаем новую колонку, где будут посчитанна сумма
orders_product_2.groupby('ID Покупателя')['Sum'].sum().sort_values(ascending=False) # Группируем Покупателя и цену
# Out:
# C:\Users\Huawei\AppData\Local\Temp\ipykernel_5176\1536968503.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_product_2['Sum'] = orders_product_2['Количество'] * orders_product_2['Price'] # Создаем новую колонку, где будут посчитанна сумма
# ID Покупателя
# 7.0    17096.0
# 5.0    13043.0
# 8.0     1344.0
# 1.0        0.0
# Name: Sum, dtype: float64

# %% [markdown]
# #### Эталонное решение

# %%
orders_product_ET['Profit'] = orders_product_ET['Price'] * orders_product_ET['Количество'] 
orders_product_ET[orders_product_ET['Оплачен'] == 'Да'].groupby('ID Покупателя')['Profit'].sum().sort_values(ascending=False)
# Out:
# ID Покупателя
# 7    17096.0
# 5    13043.0
# 8     1344.0
# 1        0.0
# Name: Profit, dtype: float64
